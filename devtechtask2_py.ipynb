# %% [markdown]
# <a href="https://colab.research.google.com/github/mekdiabrha7/internship/blob/main/devtechtask2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#task2

#file orginizer


import os
import shutil

def organize_files(folder_path):
    # Define folder categories
    file_types = {
        "Images": [".jpg", ".jpeg", ".png", ".gif", ".bmp"],
        "Documents": [".pdf", ".docx", ".doc", ".txt", ".pptx", ".xlsx"],
        "Videos": [".mp4", ".mkv", ".avi", ".mov"],
        "Music": [".mp3", ".wav", ".aac"],
        "Archives": [".zip", ".rar", ".tar", ".gz"]
    }

    # Create subfolders if they don’t exist
    for file_name in file_types.keys():
        os.makedirs(os.path.join(folder_path, category), exist_ok=True)

    # Loop through files in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Skip directories
        if os.path.isdir(file_path):
            continue

        # search file extension
        _, ext = os.path.splitext(file_name)
        ext = ext.lower()

        # Move file to matching category folder
        moved = False
        for file_name, extensions in categories.items():
            if ext in extensions:
                shutil.move(file_path, os.path.join(folder_path, category, file_name))
                moved = True
                break

        # If no file type  matches, put into "Others"
        if not moved:
            other_path = os.path.join(folder_path, "Others")
            os.makedirs(other_path, exist_ok=True)
            shutil.move(file_path, os.path.join(other_path, file_name))

    print(" Files have been organized successfully!")
